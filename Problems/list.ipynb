# %%
from typing import List

# %%
# Contain Duplication

class Solution(object):
    def containsDuplicate(self, nums):
        """
        :type nums: List[int]
        :rtype: bool
        """
        
        return len(nums) != len(set(nums))
                

print(Solution().containsDuplicate([2,14,18,22]))
# Out:
# False

# %%
class Solution(object):
    def isAnagram(self, s, t):
        """
        :type s: str
        :type t: str
        :rtype: bool
        """
        if len(s) != len(t):
            return False

        for i in set(s):
            if s.count(i) != t.count(i):
                return False
        
        return True

Solution().isAnagram('anagram', 'nagaram')
# Out:
# True

# %%
class Solution(object):
    def groupAnagrams(self, strs):
        """
        :type strs: List[str]
        :rtype: List[List[str]]
        """
        my_dict = {}
        # my_dict['ate'] = ['eat']
        # print(my_dict['eat'])

        for i in strs:
            key = ''.join(sorted(i))
                    
            if key in my_dict:
                my_dict[key].append(i)
            else:
                my_dict[key] = [i]

        return my_dict.values()





            
Solution().groupAnagrams(["eat","tea","tan","ate","nat","bat"])
# Out:
# dict_values([['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']])

# %%
# Top K Frequent Elements
class Solution(object):
    def topKFrequent(self, nums, k):
        """
        :type nums: List[int]
        :type k: int
        :rtype: List[int]
        """
        occurence = {}
        for i in set(nums):
            occurence[i] = nums.count(i)

        print(sorted(occurence.items(),reverse=True, key=lambda item: item[1]))

        return list(dict(sorted(occurence.items(),reverse=True, key=lambda item: item[1])).keys())[:k]
    

            

Solution().topKFrequent([4,1,-2,2,-2,2,3],2)
# Out:
# [(2, 2), (-2, 2), (1, 1), (3, 1), (4, 1)]
# [2, -2]

# %%
# Product of Array Except Self

from array import * 

class Solution:
    def productExceptSelf(self, nums: List[int]) -> List[int]:
        tmplt = [1] * len(nums)
        def multiple(list: List):
            product = 1
            for i in list:
                product *= i
            return product

        for i in range(len(nums)):
            tmplt[i] = multiple(nums[:i]) * multiple(nums[i+1:])

        return tmplt

        
            
       
        
Solution().productExceptSelf([-1,1,0,-3,3])
# Out:
# [0, 0, 9, 0, 0]

# %%
# Single Number

class Solution:
    def singleNumber(self, nums: List[int]) -> int:
        gate = 0
        for i in nums:
            gate ^= i
            
        return gate
            
Solution().singleNumber([4,1,2,1,2])
# Out:
# 4

# %%
# Concatination of Array.

class Solution:
    def getConcatenation(self, nums: List[int]) -> List[int]:
        n = len(nums)
        ans = []
        for i in range(n*2):
            if i < n:
                ans.append(nums[i])
            else:
                ans.append(nums[i-n])
        return ans
            
                
Solution().getConcatenation([1,2,1])
# Out:
# [1, 2, 1, 1, 2, 1]

# %%
# Remove Element

class Solution:
    def removeElement(self, nums: List[int], val: int) -> int:
        for i in range(len(nums)):
            if val in nums:
                nums.pop(nums.index(val))
            else:
                pass
        
        return len(nums)
        
        
Solution().removeElement([3,3], 3)
# Out:
# 0

# %%
# Sort an Array.

class Solution(object):
    def sortArray(self, nums):
        """
        :type nums: List[int]
        :rtype: List[int]
        """
        # for i in nums:
        nums[2] = 3 
        return nums
        
Solution().sortArray([5,1,1,2,0,0])
# Out:
# [5, 1, 3, 2, 0, 0]

# %%
arry = [3]
counter = 0
for i in arry:
    counter += 1

print(counter)
# Out:
# 1

# %%
class Solution:           
    def sortColors(self, nums: List[int]) -> None:
        l = 0 
        m = 0
        r = len(nums) - 1
        
        for i in nums:
            if nums[m] == 0:
                nums[l], nums[m] = nums[m], nums[l]
                l += 1
                m += 1
            elif nums[m] == 1:
                m += 1
            elif nums[m] == 2:
                nums[r], nums[m] = nums[m], nums[r]
                r -= 1
                
        return nums

Solution().sortColors([2,0,1])
# Out:
# [0, 1, 2]

# %%
print([1,2]*2)
# Out:
# [1, 2, 1, 2]

# %%
class NumArray:

    def __init__(self, nums: List[int]):
        self.nums = nums

    def sumRange(self, left: int, right: int) -> int:
        sum = 0
        for i in range(left, right+1):
            sum += self.nums[i]
        return sum
            
obj = NumArray([-2, 0, 3, -5, 2, -1])
obj.sumRange(0,5)
# Out:
# -3

# %%
class NumMatrix:

    def __init__(self, matrix: List[List[int]]):
        self.matrix = matrix

    def sumRegion(self, row1: int, col1: int, row2: int, col2: int) -> int:
        sum = 0
        for i in range(row1, row2+1):
            for j in range(col1, col2+1):
                sum += self.matrix[i][j]
        return sum


# Your NumMatrix object will be instantiated and called as such:
# obj = NumMatrix(matrix)
# param_1 = obj.sumRegion(row1,col1,row2,col2)

# [3, 0, |1, 4, 2|] 
# -------|-------|-
# [5, 6, |3, 2, 1|] 
# [1, 2, |0, 1, 5|]
# -------|-------|- 
# [4, 1, |0, 1, 7|] 
# [1, 0, |3, 0, 5|] 

# (1, 2, 2, 4)

# obj = NumMatrix([[3, 0, 1, 4, 2], [5, 6, 3, 2, 1], [1, 2, 0, 1, 5], [4, 1, 0, 1, 7], [1, 0, 3, 0, 5]])

# obj.sumRegion(1, 2, 2, 4)

# %%
# class Solution:
#     def listProduct(self, arr):
#         product = 1
#         for i in arr:
#             product *= i
#         return product
    
#     def productExceptSelf(self, nums: List[int]) -> List[int]:

#         result = []
#         for i in range(len(nums)):
#             result.append(self.listProduct(nums[:i]) * self.listProduct(nums[i+1:]))
#         return result


from typing import List

class Solution:
    def productExceptSelf(self, nums: List[int]) -> List[int]:
        n = len(nums)
        result = [1] * n

        # Prefix products
        prefix = 1
        for i in range(n):
            result[i] = prefix
            prefix *= nums[i]
            # print(prefix)
            # print(result)

        # Suffix products
        suffix = 1
        for i in range(n - 1, -1, -1):
            # print(i)
            result[i] *= suffix
            suffix *= nums[i]
            print(suffix)
            print(result)

        return result

    
Solution().productExceptSelf([1,2,3,4])
# Out:
# 4
# [1, 1, 2, 6]
# 12
# [1, 1, 8, 6]
# 24
# [1, 12, 8, 6]
# 24
# [24, 12, 8, 6]
# [24, 12, 8, 6]

# %%
class NumMatrix:

    def __init__(self, matrix: List[List[int]]):
        self.rows = len(matrix)
        self.cols = len(matrix[0])
        prefix = [[0 for i in range(self.cols + 1)] for j in range(self.rows + 1)]
        for i in range(self.rows):
            for j in range(self.cols):
                prefix[i + 1][j + 1] = prefix[i][j+1] + prefix[i+1][j] - prefix[i][j] + matrix[i][j]
        self.prefix = prefix
        for i in self.prefix:
            print(i)

    def sumRegion(self, row1: int, col1: int, row2: int, col2: int) -> int:
        return self.prefix[row2 + 1][col2 + 1] - self.prefix[row2 + 1][col1] - self.prefix[row1][col2 + 1] + self.prefix[row1][col1]


obj = NumMatrix([[3, 0, 1, 4, 2], [5, 6, 3, 2, 1], [1, 2, 0, 1, 5], [4, 1, 0, 1, 7], [1, 0, 3, 0, 5]])

obj.sumRegion(1, 1, 2, 2)


# [0, 0, 0, 0, 0, 0]
# [0, 3, 3|, 4, 8|, 10]
# [0, 8, 14|, 18, 24|, 27]
# [0, 9, 17, 21, 28, 36]
# [0, 13, 22, 26, 34, 49]
# [0, 14, 23, 30, 38, 58]
# Out:
# [0, 0, 0, 0, 0, 0]
# [0, 3, 3, 4, 8, 10]
# [0, 8, 14, 18, 24, 27]
# [0, 9, 17, 21, 28, 36]
# [0, 13, 22, 26, 34, 49]
# [0, 14, 23, 30, 38, 58]
# 11

# %%
print([1]*4)
# Out:
# [1, 1, 1, 1]
