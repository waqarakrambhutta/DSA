# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        s = s.lower()
        for i in s:
            if i.isalpha() or i.isdigit():
                pass
            else:
                s = s.replace(i, '')
                
        return s == s[::-1]
        
        
        
Solution().isPalindrome(" ")
# Out:
# True
